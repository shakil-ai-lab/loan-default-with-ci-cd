# %%
import joblib
import sklearn
from sklearn.metrics import classification_report, roc_curve, confusion_matrix
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import f1_score, recall_score, precision_score
# from imblearn.pipeline import Pipeline as imPipeline
# from imblearn.over_sampling import ADASYN
import warnings
warnings.filterwarnings("ignore")

# %%
# ! pip install imblearn 
! pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sanja\miniconda3\envs\ml_env\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14

# %%
# load cleaned dataset
df = joblib.load("../src/cleaned_loan_df.pkl")
df.head(1)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
#
#    InterestRate  LoanTerm  DTIRatio   Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44  Bachelor's      Full-time      Divorced
#
#   HasMortgage HasDependents LoanPurpose HasCoSigner  Default
# 0         Yes           Yes       Other         Yes        0

# %%
X = df.drop("Default", axis=1)
y = df["Default"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.3, random_state=42)

# %%
joblib.dump(X_train, "../src/X_train.pkl")
joblib.dump(X_test, "../src/X_test.pkl")
joblib.dump(y_train, "../src/y_train.pkl")
joblib.dump(y_test, "../src/y_test.pkl")
# Out:
# ['../src/y_test.pkl']

# %%
# X_test

# %%
# load column transformer
encoding = joblib.load("../src/encoder.pkl")
scaling = joblib.load("../src/scaler.pkl"
)

# %%
# 3 load features dictinoary
features_dict = joblib.load("../src/features_config.pkl")

# %%
encoding
# Out:
# ColumnTransformer(transformers=[('num', 'passthrough',
#                                  ['Age', 'Income', 'LoanAmount', 'CreditScore',
#                                   'MonthsEmployed', 'NumCreditLines',
#                                   'InterestRate', 'LoanTerm', 'DTIRatio']),
#                                 ('cat', OneHotEncoder(drop='first'),
#                                  ['EmploymentType', 'MaritalStatus',
#                                   'LoanPurpose']),
#                                 ('bin',
#                                  OrdinalEncoder(categories=[['No', 'Yes'],
#                                                             ['No', 'Yes'],
#                                                             ['No', 'Yes']]),
#                                  ['HasCoSigner', 'HasMortgage',
#                                   'HasDependents']),
#                                 ('ord',
#                                  OrdinalEncoder(categories=[['High School',
#                                                              "Bachelor's",
#                                                              "Master's",
#                                                              'PhD']]),
#                                  ['Education'])])

# %%
features_dict["numeric_features"]
# Out:
# ['Age',
#  'Income',
#  'LoanAmount',
#  'CreditScore',
#  'MonthsEmployed',
#  'NumCreditLines',
#  'InterestRate',
#  'LoanTerm',
#  'DTIRatio']

# %%
# ! pip install -r ../requirements.txt
# ! pip install scikit-learn==1.1.3

# %%
from xgboost import XGBClassifier
from sklearn.base import BaseEstimator, ClassifierMixin

class SklearnXGBWrapper(XGBClassifier, BaseEstimator, ClassifierMixin):
    def __sklearn_tags__(self):
        return {"binary_only": False, "requires_y": True}

# %%
# Optuna objective
def objective(trial):
    model_type = trial.suggest_categorical("model_type", ["LogReg", "RF"])

    if model_type == "LogReg":
        C = trial.suggest_loguniform("C", 1e-4, 1e2)
        penalty = trial.suggest_categorical("penalty", ["l1", "l2"])
        solver = "liblinear" if penalty == "l1" else "lbfgs"
        clf = LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=1000)
    elif model_type == "RF":
        n_estimators = trial.suggest_int("n_estimators", 100, 300)
        max_depth = trial.suggest_int("max_depth", 3, 10)
        clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
    else:  # XGB
        n_estimators = trial.suggest_int("n_estimators", 100, 300)
        max_depth = trial.suggest_int("max_depth", 3, 10)
        learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
        # clf = xgb.XGBClassifier(n_estimators=n_estimators, max_depth=max_depth,
        #                         learning_rate=learning_rate, eval_metric='logloss', use_label_encoder=False)
        clf = SklearnXGBWrapper(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        eval_metric='logloss',
        use_label_encoder=False
)


    pipeline = imPipeline([
        ("encoding", encoding),
        ("adasyn", ADASYN(random_state=42)),
        ("scaling", scaling),
        ("classifier", clf)
    ])

    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)

    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    trial.set_user_attr("precision", prec)
    trial.set_user_attr("recall", rec)

    return f1

# 6. Run study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

# 7. Show best params
print("Best params:", study.best_params)

# 8. Train best pipeline again with predict_proba
best_model_type = study.best_params["model_type"]

if best_model_type == "LogReg":
    C = study.best_params["C"]
    penalty = study.best_params["penalty"]
    solver = "liblinear" if penalty == "l1" else "lbfgs"
    best_clf = LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=1000)
elif best_model_type == "RF":
    best_clf = RandomForestClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=study.best_params["max_depth"],
        random_state=42
    )
else:
    best_clf = xgb.XGBClassifier(
        n_estimators=study.best_params["n_estimators"],
        max_depth=study.best_params["max_depth"],
        learning_rate=study.best_params["learning_rate"],
        eval_metric='logloss',
        use_label_encoder=False
    )

final_pipeline = imPipeline([
    ("encoding", encoding),
    ("adasyn", ADASYN(random_state=42)),
    ("scaling", scaling),
    ("classifier", best_clf)
])

final_pipeline = final_pipeline.fit(X_train, y_train)
metadata = {
    "model": final_pipeline,
    "sklearn_version": sklearn.__version__
}
joblib.dump(metadata, "final_pipeline_with_meta.pkl")

joblib.dump(study, "study.pkl")
# Out:
# [I 2025-07-17 10:53:27,043] A new study created in memory with name: no-name-4d8021ab-9a67-4e74-a24a-337131f574f6
# [I 2025-07-17 10:53:40,089] Trial 0 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 66.48180886510872, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:53:46,778] Trial 1 finished with value: 0.3304737038418501 and parameters: {'model_type': 'LogReg', 'C': 18.774481092661983, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:53:51,903] Trial 2 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 1.5327150389974555, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:53:56,993] Trial 3 finished with value: 0.33046489942720125 and parameters: {'model_type': 'LogReg', 'C': 0.039589883651375564, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:54:58,435] Trial 4 finished with value: 0.1446898959993927 and parameters: {'model_type': 'RF', 'n_estimators': 102, 'max_depth': 5}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:56:57,327] Trial 5 finished with value: 0.1787841109875008 and parameters: {'model_type': 'RF', 'n_estimators': 218, 'max_depth': 4}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:57:49,952] Trial 6 finished with value: 0.207910208444682 and parameters: {'model_type': 'RF', 'n_estimators': 124, 'max_depth': 3}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 10:57:55,243] Trial 7 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 2.6589339033640202, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:00:55,977] Trial 8 finished with value: 0.1086411210102932 and parameters: {'model_type': 'RF', 'n_estimators': 277, 'max_depth': 6}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:06,518] Trial 9 finished with value: 0.021947283485745022 and parameters: {'model_type': 'RF', 'n_estimators': 296, 'max_depth': 10}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:11,461] Trial 10 finished with value: 0.3188073394495413 and parameters: {'model_type': 'LogReg', 'C': 0.00017920401131726703, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:18,384] Trial 11 finished with value: 0.33048250872565477 and parameters: {'model_type': 'LogReg', 'C': 79.20488916384937, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:23,764] Trial 12 finished with value: 0.33048250872565477 and parameters: {'model_type': 'LogReg', 'C': 0.9358588154666966, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:31,015] Trial 13 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 70.59643686527862, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:36,381] Trial 14 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 1.7702818306867092, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:43,245] Trial 15 finished with value: 0.33042922228438976 and parameters: {'model_type': 'LogReg', 'C': 0.10539869744305538, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:48,528] Trial 16 finished with value: 0.3304913140786529 and parameters: {'model_type': 'LogReg', 'C': 10.769275774844353, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:05:54,082] Trial 17 finished with value: 0.3304913140786529 and parameters: {'model_type': 'LogReg', 'C': 10.378008646186926, 'penalty': 'l2'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:06:01,213] Trial 18 finished with value: 0.33048250872565477 and parameters: {'model_type': 'LogReg', 'C': 90.2527735728231, 'penalty': 'l1'}. Best is trial 0 with value: 0.3305001199008819.
# [I 2025-07-17 11:06:08,292] Trial 19 finished with value: 0.3305089261923794 and parameters: {'model_type': 'LogReg', 'C': 0.22980268377099983, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:15,324] Trial 20 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 0.19026935318339827, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:22,772] Trial 21 finished with value: 0.33048250872565477 and parameters: {'model_type': 'LogReg', 'C': 0.4279148400474759, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:29,991] Trial 22 finished with value: 0.330420884389984 and parameters: {'model_type': 'LogReg', 'C': 0.047906849109930386, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:35,615] Trial 23 finished with value: 0.3305001199008819 and parameters: {'model_type': 'LogReg', 'C': 3.270842928196486, 'penalty': 'l2'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:43,174] Trial 24 finished with value: 0.33048250872565477 and parameters: {'model_type': 'LogReg', 'C': 0.5024981074430319, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:06:50,613] Trial 25 finished with value: 0.3304913140786529 and parameters: {'model_type': 'LogReg', 'C': 6.8760150696565905, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:09:19,352] Trial 26 finished with value: 0.028154106689246398 and parameters: {'model_type': 'RF', 'n_estimators': 178, 'max_depth': 9}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:09:24,545] Trial 27 finished with value: 0.3304913140786529 and parameters: {'model_type': 'LogReg', 'C': 25.847137672400653, 'penalty': 'l2'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:09:31,368] Trial 28 finished with value: 0.3304737038418501 and parameters: {'model_type': 'LogReg', 'C': 2.9451418316620748, 'penalty': 'l1'}. Best is trial 19 with value: 0.3305089261923794.
# [I 2025-07-17 11:09:36,727] Trial 29 finished with value: 0.330500572768202 and parameters: {'model_type': 'LogReg', 'C': 0.020631690484911272, 'penalty': 'l2'}. Best is trial 19 with value: 0.3305089261923794.
# Best params: {'model_type': 'LogReg', 'C': 0.22980268377099983, 'penalty': 'l1'}
# ['study.pkl']

# %%
# joblib.dump(metadata, "../src/final_pipeline_with_meta.pkl")
joblib.dump(study, "../src/study.pkl")
# Out:
# ['../src/study.pkl']

# %%
best_model = LogisticRegression(C = 0.10728990079492859, penalty='l1', solver="liblinear", max_iter=1000)

# %%
joblib.dump(final_pipeline, "../src/final_pipeline.pkl")
# Out:
# ['../src/final_pipeline.pkl']

# %%
# Note:
# 1. we could not use feature names in scaling bcz after column transformer we get numpy arrays,
# 2. our logic of scaling by slice is also wrong bcz our feature columns will append at last of our data.
# 3. we will putt numeric features at start of column transformer, which have put
import sklearn
print(sklearn.__version__)
# Out:
# 1.1.3

# %%
study_df[(study_df.params_model_type == "LogReg") & (study_df.user_attrs_recall>0.67)]
# Out:
#     number     value             datetime_start          datetime_complete  \
# 3        3  0.330722 2025-07-10 00:30:25.543520 2025-07-10 00:31:10.131958
# 5        5  0.330491 2025-07-10 00:37:22.351721 2025-07-10 00:38:26.661882
# 9        9  0.330483 2025-07-10 00:42:46.941187 2025-07-10 00:43:54.770512
# 10      10  0.325089 2025-07-10 00:43:54.774526 2025-07-10 00:44:32.672091
# 11      11  0.330491 2025-07-10 00:44:32.673089 2025-07-10 00:45:15.166831
# 12      12  0.330420 2025-07-10 00:45:15.167830 2025-07-10 00:46:02.442618
# 13      13  0.330420 2025-07-10 00:46:02.443617 2025-07-10 00:46:45.108861
# 14      14  0.330491 2025-07-10 00:46:45.110860 2025-07-10 00:47:41.153484
# 15      15  0.330474 2025-07-10 00:47:41.157482 2025-07-10 00:48:49.771023
# 16      16  0.330500 2025-07-10 00:48:49.773020 2025-07-10 00:49:50.478838
# 18      18  0.330483 2025-07-10 00:58:14.357750 2025-07-10 00:59:07.373562
# 19      19  0.330947 2025-07-10 00:59:07.374561 2025-07-10 00:59:46.927122
# 21      21  0.330582 2025-07-10 01:13:36.883773 2025-07-10 01:14:24.287480
# 22      22  0.330470 2025-07-10 01:14:24.288478 2025-07-10 01:15:05.455042
# 23      23  0.331019 2025-07-10 01:15:05.457040 2025-07-10 01:15:52.519961
# 24      24  0.330766 2025-07-10 01:15:52.521959 2025-07-10 01:16:39.694808
# 25      25  0.317337 2025-07-10 01:16:39.696809 2025-07-10 01:17:20.819397
# 26      26  0.330636 2025-07-10 01:17:20.820396 2025-07-10 01:18:04.105649
# 27      27  0.330756 2025-07-10 01:18:04.109426 2025-07-10 01:19:22.594003
# 28      28  0.330773 2025-07-10 01:19:22.596001 2025-07-10 01:20:38.686095
#
#                  duration   params_C  params_learning_rate  params_max_depth  \
# 3  0 days 00:00:44.588438   0.019259                   NaN               NaN
# 5  0 days 00:01:04.310161  16.624916                   NaN               NaN
# 9  0 days 00:01:07.829325   1.591114                   NaN               NaN
# 10 0 days 00:00:37.897565   0.000383                   NaN               NaN
# 11 0 days 00:00:42.493742  82.815265                   NaN               NaN
# 12 0 days 00:00:47.274788   0.012451                   NaN               NaN
# 13 0 days 00:00:42.665244   0.103146                   NaN               NaN
# 14 0 days 00:00:56.042624  64.453093                   NaN               NaN
# 15 0 days 00:01:08.613541   0.055605                   NaN               NaN
# 16 0 days 00:01:00.705818   1.226054                   NaN               NaN
# 18 0 days 00:00:53.015812   1.006504                   NaN               NaN
# 19 0 days 00:00:39.552561   0.001657                   NaN               NaN
# 21 0 days 00:00:47.403707   0.001848                   NaN               NaN
# 22 0 days 00:00:41.166564   0.001003                   NaN               NaN
# 23 0 days 00:00:47.062921   0.003007                   NaN               NaN
# 24 0 days 00:00:47.172849   0.006063                   NaN               NaN
# 25 0 days 00:00:41.122588   0.000144                   NaN               NaN
# 26 0 days 00:00:43.285253   0.002730                   NaN               NaN
# 27 0 days 00:01:18.484577   0.010196                   NaN               NaN
# 28 0 days 00:01:16.090094   0.004107                   NaN               NaN
#
#    params_model_type  params_n_estimators params_penalty  \
# 3             LogReg                  NaN             l1
# 5             LogReg                  NaN             l2
# 9             LogReg                  NaN             l1
# 10            LogReg                  NaN             l1
# 11            LogReg                  NaN             l2
# 12            LogReg                  NaN             l2
# 13            LogReg                  NaN             l1
# 14            LogReg                  NaN             l2
# 15            LogReg                  NaN             l2
# 16            LogReg                  NaN             l1
# 18            LogReg                  NaN             l1
# 19            LogReg                  NaN             l1
# 21            LogReg                  NaN             l1
# 22            LogReg                  NaN             l1
# 23            LogReg                  NaN             l1
# 24            LogReg                  NaN             l1
# 25            LogReg                  NaN             l1
# 26            LogReg                  NaN             l1
# 27            LogReg                  NaN             l1
# 28            LogReg                  NaN             l1
#
#     user_attrs_precision  user_attrs_recall     state
# 3               0.216958           0.695316  COMPLETE
# 5               0.216793           0.694980  COMPLETE
# 9               0.216785           0.694980  COMPLETE
# 10              0.213774           0.678283  COMPLETE
# 11              0.216793           0.694980  COMPLETE
# 12              0.216742           0.694868  COMPLETE
# 13              0.216742           0.694868  COMPLETE
# 14              0.216793           0.694980  COMPLETE
# 15              0.216777           0.694980  COMPLETE
# 16              0.216800           0.694980  COMPLETE
# 18              0.216785           0.694980  COMPLETE
# 19              0.217262           0.694195  COMPLETE
# 21              0.217024           0.693411  COMPLETE
# 22              0.217081           0.691842  COMPLETE
# 23              0.217280           0.694644  COMPLETE
# 24              0.216996           0.695316  COMPLETE
# 25              0.206531           0.684671  COMPLETE
# 26              0.217038           0.693747  COMPLETE
# 27              0.217010           0.695092  COMPLETE
# 28              0.217035           0.694980  COMPLETE

# %%
study_df = study.trials_dataframe()
